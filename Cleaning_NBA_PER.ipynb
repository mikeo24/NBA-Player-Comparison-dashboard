# %%
import pandas as pd

# %%
per = pd.read_csv("advanced.csv")

# %%
per.head()
# Out:
#    Unnamed: 0 Rk            Player Pos Age   Tm   G    MP   PER   TS%  ...  \
# 0           0  1  Precious Achiuwa   C  23  TOR  39   896  15.0  .546  ...
# 1           1  2      Steven Adams   C  29  MEM  42  1133  17.6  .564  ...
# 2           2  3       Bam Adebayo   C  25  MIA  57  1997  20.7  .587  ...
# 3           3  4      Ochai Agbaji  SG  22  UTA  40   629   9.3  .612  ...
# 4           4  5      Santi Aldama  PF  22  MEM  57  1247  14.6  .596  ...
#
#    OWS  DWS   WS WS/48 Unnamed: 24  OBPM  DBPM   BPM  VORP  Year
# 0  0.6  1.0  1.6  .088         NaN  -1.6  -1.0  -2.6  -0.1  2023
# 1  1.3  2.2  3.5  .146         NaN  -0.3   0.9   0.6   0.8  2023
# 2  2.8  3.3  6.0  .145         NaN   0.9   1.0   1.9   2.0  2023
# 3  0.8  0.2  1.0  .076         NaN  -1.2  -1.2  -2.4  -0.1  2023
# 4  1.8  2.0  3.8  .145         NaN   0.0   1.3   1.3   1.0  2023
#
# [5 rows x 31 columns]

# %%
per.columns
# Out:
# Index(['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48',
#        'Unnamed: 24', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Year'],
#       dtype='object')

# %% [markdown]
# ### Directory
#
#
# PER is an abbreviation for Player Efficiency Rating. It is a statistic used to measure the overall efficiency of a player in a basketball game. The statistic is calculated by taking a player’s total offensive and defensive contributions and dividing them by the number of minutes they are on the court. The higher the rating, the more efficient the player is.
#
# TS%: True Shooting Percentage - A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws.
#
# 3PAr: Three Point Attempt Rate - The percentage of field goal attempts that are three pointers.
#
# FTr: Free Throw Attempt Rate - The percentage of field goal attempts that are free throws.
#
# ORB%: Offensive Rebound Percentage - An estimate of the percentage of available offensive rebounds a player grabbed while he was on the floor.
#
# DRB%: Defensive Rebound Percentage - An estimate of the percentage of available defensive rebounds a player grabbed while he was on the floor.
#
# TRB%: Total Rebound Percentage - An estimate of the percentage of available rebounds a player grabbed while he was on the floor.
#
# AST%: Assist Percentage - An estimate of the percentage of teammate field goals a player assisted while he was on the floor.
#
# STL%: Steal Percentage - An estimate of the percentage of opponent possessions that end with a steal by the player while he was on the floor.

# %%
per.dtypes
# Out:
# Unnamed: 0       int64
# Rk              object
# Player          object
# Pos             object
# Age             object
# Tm              object
# G               object
# MP              object
# PER             object
# TS%             object
# 3PAr            object
# FTr             object
# ORB%            object
# DRB%            object
# TRB%            object
# AST%            object
# STL%            object
# BLK%            object
# TOV%            object
# USG%            object
# Unnamed: 19    float64
# OWS             object
# DWS             object
# WS              object
# WS/48           object
# Unnamed: 24    float64
# OBPM            object
# DBPM            object
# BPM             object
# VORP            object
# Year             int64
# dtype: object

# %%
per[per["Player"]=="A.J. Lawson"]
# Out:
#      Unnamed: 0   Rk       Player Pos Age   Tm   G  MP   PER    TS%  ...  OWS  \
# 346         346  273  A.J. Lawson  SG  22  TOT  13  63  14.3   .622  ...  0.1
# 347         347  273  A.J. Lawson  SG  22  MIN   1   2  34.7  1.000  ...  0.0
# 348         348  273  A.J. Lawson  SG  22  DAL  12  61  13.6   .608  ...  0.1
#
#      DWS   WS WS/48 Unnamed: 24  OBPM  DBPM   BPM VORP  Year
# 346  0.0  0.1  .091         NaN  -0.7  -2.1  -2.7  0.0  2023
# 347  0.0  0.0  .381         NaN  -2.3   7.6   5.3  0.0  2023
# 348  0.0  0.1  .081         NaN  -0.6  -2.4  -3.0  0.0  2023
#
# [3 rows x 31 columns]

# %%
def single_row(df1):
    if df1.shape[0]==1:    #If there's only one row for that specific player return the data
        return df1
    else:
        row = df1[df1["Tm"] == "TOT"]       #If they have multiple teams they payed for just return their total stats (TOT)
        row["Tm"] = df1.iloc[-1,:]["Tm"]   #replace TOT with the last team that player played for in the last row
        return row
    
per = per.groupby(["Player", "Year"]).apply(single_row)

# %%
per.index = per.index.droplevel()

# %%
per.index = per.index.droplevel()

# %%
per = per[['Player', 'PER','USG%', 'TS%', '3PAr', 'FTr', 'TRB%', 'AST%', 'STL%', 'BLK%', 'Year']]

# %%
per
# Out:
#               Player   PER  USG%   TS%  3PAr   FTr  TRB%  AST% STL% BLK%  Year
# 207       A.J. Green  12.8  17.1  .630  .828  .040   6.0   9.6  1.1  0.0  2023
# 346      A.J. Lawson  14.3  20.3  .622  .615  .115   9.3   2.6  0.8  0.0  2023
# 217       AJ Griffin  12.6  17.6  .580  .489  .073   5.5   6.9  1.6  0.5  2023
# 199     Aaron Gordon  20.7  21.4  .641  .231  .435  13.2  14.1  1.3  2.3  2023
# 257    Aaron Holiday   8.8  13.4  .527  .399  .149   4.9  11.1  1.8  1.2  2023
# ..               ...   ...   ...   ...   ...   ...   ...   ...  ...  ...   ...
# 116     Zach Collins  15.4  20.2  .590  .239  .283  15.4  17.6  1.1  2.5  2023
# 345      Zach LaVine  18.0  27.8  .597  .410  .307   7.5  17.5  1.3  0.6  2023
# 439       Zeke Nnaji  13.4  14.5  .634  .296  .355  10.1   2.5  1.3  2.9  2023
# 638  Ziaire Williams   6.3  16.5  .499  .513  .106   7.5   6.4  1.2  0.9  2023
# 639  Zion Williamson  25.4  30.1  .652  .041  .529  11.9  24.4  1.6  1.6  2023
#
# [511 rows x 11 columns]

# %%
player = pd.read_csv("player.csv")

# %%
player.head()
# Out:
#    Unnamed: 0 Rk            Player Pos Age   Tm   G  GS    MP   FG  ...  ORB  \
# 0           0  1  Precious Achiuwa   C  23  TOR  39  11  23.0  3.8  ...  2.1
# 1           1  2      Steven Adams   C  29  MEM  42  42  27.0  3.7  ...  5.1
# 2           2  3       Bam Adebayo   C  25  MIA  57  57  35.0  8.4  ...  2.6
# 3           3  4      Ochai Agbaji  SG  22  UTA  40   3  15.7  1.9  ...  0.7
# 4           4  5      Santi Aldama  PF  22  MEM  57  18  21.9  3.3  ...  1.0
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  4.4   6.5  1.0  0.6  0.6  1.2  2.1  10.1  2023
# 1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6  2023
# 2  7.2   9.8  3.2  1.2  0.8  2.5  2.8  21.2  2023
# 3  1.1   1.8  0.6  0.2  0.2  0.4  1.4   5.1  2023
# 4  3.6   4.6  1.2  0.7  0.7  0.7  1.9   9.3  2023
#
# [5 rows x 32 columns]

# %%
player.columns
# Out:
# Index(['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG',
#        'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'Year'],
#       dtype='object')

# %%
del player['Unnamed: 0']

# %%
player.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# Year       int64
# dtype: object

# %%
player.groupby(["Player","Year"]).get_group(("Russell Westbrook", 2023))
# Out:
#       Rk             Player Pos Age   Tm   G GS    MP   FG   FGA  ...  ORB  \
# 619  485  Russell Westbrook  PG  34  TOT  55  6  28.8  5.9  13.9  ...  1.1
# 620  485  Russell Westbrook  PG  34  LAL  52  3  28.7  5.8  14.0  ...  1.1
# 621  485  Russell Westbrook  PG  34  LAC   3  3  31.0  6.0  11.3  ...  1.0
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 619  5.0  6.1  7.6  1.1  0.4  3.6  2.4  15.9  2023
# 620  5.0  6.2  7.5  1.0  0.4  3.5  2.3  15.9  2023
# 621  4.7  5.7  9.3  2.3  0.0  4.3  3.7  16.0  2023
#
# [3 rows x 31 columns]

# %%
def single_row(df):
    if df.shape[0]==1:    #If there's only one row for that specific player return the data
        return df
    else:
        row = df[df["Tm"] == "TOT"]       #If they have multiple teams they payed for just return their total stats (TOT)
        row["Tm"] = df.iloc[-1,:]["Tm"]   #replace TOT with the last team that player played for in the last row
        return row
    
player = player.groupby(["Player", "Year"]).apply(single_row)

# %%
player.shape
# Out:
# (511, 31)

# %%
player
# Out:
#                            Rk           Player Pos Age   Tm   G  GS    MP  \
# Player          Year
# A.J. Green      2023 207  167       A.J. Green  SG  23  MIL  28   0   9.5
# A.J. Lawson     2023 346  273      A.J. Lawson  SG  22  DAL  13   0   4.8
# AJ Griffin      2023 217  175       AJ Griffin  SF  19  ATL  58  11  20.2
# Aaron Gordon    2023 199  163     Aaron Gordon  PF  27  DEN  51  51  30.1
# Aaron Holiday   2023 257  205    Aaron Holiday  PG  26  ATL  51   5  14.3
# ...                       ...              ...  ..  ..  ...  ..  ..   ...
# Zach Collins    2023 116   94     Zach Collins   C  25  SAS  51  14  21.5
# Zach LaVine     2023 345  272      Zach LaVine  SG  27  CHI  58  58  35.9
# Zeke Nnaji      2023 439  346       Zeke Nnaji  PF  22  DEN  44   5  13.3
# Ziaire Williams 2023 638  501  Ziaire Williams  SF  21  MEM  30   3  16.4
# Zion Williamson 2023 639  502  Zion Williamson  PF  22  NOP  29  29  33.0
#
# ...

# %%
player.index = player.index.droplevel()

# %%
player.index = player.index.droplevel()

# %%
player.head()
# Out:
#       Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  DRB  \
# 207  167     A.J. Green  SG  23  MIL  28   0   9.5  1.6   3.5  ...  0.2  0.9
# 346  273    A.J. Lawson  SG  22  DAL  13   0   4.8  1.0   2.0  ...  0.2  0.6
# 217  175     AJ Griffin  SF  19  ATL  58  11  20.2  3.6   7.6  ...  0.4  1.6
# 199  163   Aaron Gordon  PF  27  DEN  51  51  30.1  6.5  11.1  ...  2.4  4.5
# 257  205  Aaron Holiday  PG  26  ATL  51   5  14.3  1.5   3.7  ...  0.4  0.9
#
#      TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 207  1.1  0.6  0.2  0.0  0.3  0.9   4.5  2023
# 346  0.8  0.1  0.1  0.0  0.1  0.6   2.6  2023
# 217  2.1  1.0  0.7  0.1  0.6  1.3   9.1  2023
# 199  6.8  3.0  0.8  0.8  1.6  1.9  17.0  2023
# 257  1.3  1.3  0.5  0.2  0.6  1.3   4.1  2023
#
# [5 rows x 31 columns]

# %%
player[player["Player"]=="Russell Westbrook"]
# Out:
#       Rk             Player Pos Age   Tm   G GS    MP   FG   FGA  ...  ORB  \
# 619  485  Russell Westbrook  PG  34  LAC  55  6  28.8  5.9  13.9  ...  1.1
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 619  5.0  6.1  7.6  1.1  0.4  3.6  2.4  15.9  2023
#
# [1 rows x 31 columns]

# %%
combined = player.merge(per, how="outer", on = ["Player", "Year"])

# %%
combined.head(5)
# Out:
#     Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  Year   PER  \
# 0  167     A.J. Green  SG  23  MIL  28   0   9.5  1.6   3.5  ...  2023  12.8
# 1  273    A.J. Lawson  SG  22  DAL  13   0   4.8  1.0   2.0  ...  2023  14.3
# 2  175     AJ Griffin  SF  19  ATL  58  11  20.2  3.6   7.6  ...  2023  12.6
# 3  163   Aaron Gordon  PF  27  DEN  51  51  30.1  6.5  11.1  ...  2023  20.7
# 4  205  Aaron Holiday  PG  26  ATL  51   5  14.3  1.5   3.7  ...  2023   8.8
#
#    USG%   TS%  3PAr   FTr  TRB%  AST% STL% BLK%
# 0  17.1  .630  .828  .040   6.0   9.6  1.1  0.0
# 1  20.3  .622  .615  .115   9.3   2.6  0.8  0.0
# 2  17.6  .580  .489  .073   5.5   6.9  1.6  0.5
# 3  21.4  .641  .231  .435  13.2  14.1  1.3  2.3
# 4  13.4  .527  .399  .149   4.9  11.1  1.8  1.2
#
# [5 rows x 40 columns]

# %%
del combined['Rk']

# %%
combined
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  Year  \
# 0         A.J. Green  SG  23  MIL  28   0   9.5  1.6   3.5  .444  ...  2023
# 1        A.J. Lawson  SG  22  DAL  13   0   4.8  1.0   2.0  .500  ...  2023
# 2         AJ Griffin  SF  19  ATL  58  11  20.2  3.6   7.6  .473  ...  2023
# 3       Aaron Gordon  PF  27  DEN  51  51  30.1  6.5  11.1  .585  ...  2023
# 4      Aaron Holiday  PG  26  ATL  51   5  14.3  1.5   3.7  .415  ...  2023
# ..               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 506     Zach Collins   C  25  SAS  51  14  21.5  3.9   7.6  .517  ...  2023
# 507      Zach LaVine  SG  27  CHI  58  58  35.9  8.4  17.7  .472  ...  2023
# 508       Zeke Nnaji  PF  22  DEN  44   5  13.3  2.0   3.5  .572  ...  2023
# 509  Ziaire Williams  SF  21  MEM  30   3  16.4  2.2   5.3  .419  ...  2023
# 510  Zion Williamson  PF  22  NOP  29  29  33.0  9.8  16.2  .608  ...  2023
#
#       PER  USG%   TS%  3PAr   FTr  TRB%  AST% STL% BLK%
# ...

# %%
combined = combined.apply(pd.to_numeric, errors="ignore")  #This means it will go through columns in stats and try to convert them into numeric columns.

# And if there's an error it won't convert

combined.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Year        int64
# PER       float64
# USG%      float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# dtype: object

# %%
combined = combined[combined['PER'] > 20]

# %%
combined.head(20)
# Out:
#                     Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 3             Aaron Gordon  PF   27  DEN  51  51  30.1   6.5  11.1  0.585
# 15          Alperen Şengün   C   20  HOU  56  53  28.1   5.8  10.6  0.551
# 17          Andre Drummond   C   29  CHI  49   0  13.1   2.7   4.4  0.621
# 22           Anthony Davis   C   29  LAL  38  36  33.3   9.7  17.3  0.561
# 29             Bam Adebayo   C   25  MIA  57  57  35.0   8.4  15.7  0.536
# 35        Boban Marjanović   C   34  HOU  21   0   4.5   1.3   2.0  0.683
# 41            Bradley Beal  SG   29  WAS  39  39  33.1   8.9  17.2  0.517
# 43          Brandon Clarke  PF   26  MEM  54   8  19.8   4.2   6.4  0.662
# 73          Christian Wood   C   27  DAL  51  17  27.2   6.4  12.2  0.522
# 75            Clint Capela   C   28  ATL  46  44  26.8   5.4   8.7  0.627
# 89          Damian Lillard  PG   32  POR  48  48  36.2   9.7  20.6  0.471
# 91          Daniel Gafford   C   24  WAS  59  28  19.1   3.4   4.6  0.749
# ...

# %%
combined.shape
# Out:
# (66, 39)

# %%
combined.isnull().sum()
# Out:
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       6
# 2P        0
# 2PA       0
# 2P%       1
# eFG%      0
# FT        0
# FTA       0
# FT%       6
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# Year      0
# PER       0
# USG%      0
# TS%       0
# 3PAr      0
# FTr       0
# TRB%      0
# AST%      0
# STL%      0
# BLK%      0
# dtype: int64

# %%
combined[["FG%", "3P%", "2P%", "eFG%", "FT%", "TS%", "3PAr", "FTr"]] = combined[["FG%", "3P%", "2P%", "eFG%", "FT%", "TS%", "3PAr", "FTr"]].fillna(0)

# %%
combined.sort_values(by='PER', ascending=False)
# Out:
#               Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 445    Stanley Umude  SG   23  DET   1   0   2.0   0.0   1.0  0.000  ...
# 483     Tyler Dorsey  SG   26  DAL   3   0   2.7   1.3   1.7  0.800  ...
# 380     Nikola Jokić   C   27  DEN  55  55  33.6   9.4  14.8  0.633  ...
# 241      Joel Embiid   C   28  PHI  48  48  35.1  10.9  20.6  0.532  ...
# 325      Luka Dončić  PG   23  DAL  53  53  36.4  11.2  22.2  0.506  ...
# ..               ...  ..  ...  ...  ..  ..   ...   ...   ...    ...  ...
# 43    Brandon Clarke  PF   26  MEM  54   8  19.8   4.2   6.4  0.662  ...
# 220    Jarrett Allen   C   24  CLE  57  57  33.2   6.2   9.4  0.654  ...
# 418  Robert Williams   C   25  BOS  26  16  24.2   3.9   5.2  0.750  ...
# 344    Mason Plumlee   C   32  LAC  61  58  27.9   4.5   6.7  0.676  ...
# 15    Alperen Şengün   C   20  HOU  56  53  28.1   5.8  10.6  0.551  ...
#
#      Year   PER  USG%    TS%   3PAr    FTr  TRB%  AST%  STL%  BLK%
# ...

# %%
combined = combined[combined["MP"]> 30]

# %%
combined
# Out:
#                       Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 3               Aaron Gordon  PF   27  DEN  51  51  30.1   6.5  11.1  0.585
# 22             Anthony Davis   C   29  LAL  38  36  33.3   9.7  17.3  0.561
# 29               Bam Adebayo   C   25  MIA  57  57  35.0   8.4  15.7  0.536
# 41              Bradley Beal  SG   29  WAS  39  39  33.1   8.9  17.2  0.517
# 89            Damian Lillard  PG   32  POR  48  48  36.2   9.7  20.6  0.471
# 104             De'Aaron Fox  PG   25  SAC  55  55  34.1   9.4  18.3  0.515
# 108            DeMar DeRozan  SF   33  CHI  56  56  36.1   9.1  17.8  0.509
# 110            Deandre Ayton   C   24  PHO  53  53  30.3   8.2  13.8  0.591
# 122             Devin Booker  SG   26  PHO  35  35  34.1   9.5  20.1  0.473
# 128         Domantas Sabonis   C   26  SAC  59  59  34.5   7.1  11.5  0.614
# 130         Donovan Mitchell  SG   26  CLE  53  53  35.4   9.5  19.8  0.479
# ...

# %%
combined = combined.sort_values(by='PER', ascending=False).reset_index()

# %%
del combined['index']

# %%
combined
# Out:
#                      Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 0              Nikola Jokić   C   27  DEN  55  55  33.6   9.4  14.8  0.633
# 1               Joel Embiid   C   28  PHI  48  48  35.1  10.9  20.6  0.532
# 2               Luka Dončić  PG   23  DAL  53  53  36.4  11.2  22.2  0.506
# 3     Giannis Antetokounmpo  PF   28  MIL  49  49  32.4  11.2  20.8  0.539
# 4             Anthony Davis   C   29  LAL  38  36  33.3   9.7  17.3  0.561
# 5   Shai Gilgeous-Alexander  PG   24  OKC  54  54  35.5  10.2  20.2  0.507
# 6            Damian Lillard  PG   32  POR  48  48  36.2   9.7  20.6  0.471
# 7              Kevin Durant  PF   34  BRK  39  39  36.0  10.5  18.8  0.559
# 8              Jimmy Butler  SF   33  MIA  47  47  33.4   7.2  14.0  0.518
# 9           Zion Williamson  PF   22  NOP  29  29  33.0   9.8  16.2  0.608
# 10            Stephen Curry  PG   34  GSW  38  38  34.6   9.8  19.8  0.495
# ...

# %%
combined = combined[:16]
combined
# Out:
#                      Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 0              Nikola Jokić   C   27  DEN  55  55  33.6   9.4  14.8  0.633
# 1               Joel Embiid   C   28  PHI  48  48  35.1  10.9  20.6  0.532
# 2               Luka Dončić  PG   23  DAL  53  53  36.4  11.2  22.2  0.506
# 3     Giannis Antetokounmpo  PF   28  MIL  49  49  32.4  11.2  20.8  0.539
# 4             Anthony Davis   C   29  LAL  38  36  33.3   9.7  17.3  0.561
# 5   Shai Gilgeous-Alexander  PG   24  OKC  54  54  35.5  10.2  20.2  0.507
# 6            Damian Lillard  PG   32  POR  48  48  36.2   9.7  20.6  0.471
# 7              Kevin Durant  PF   34  BRK  39  39  36.0  10.5  18.8  0.559
# 8              Jimmy Butler  SF   33  MIA  47  47  33.4   7.2  14.0  0.518
# 9           Zion Williamson  PF   22  NOP  29  29  33.0   9.8  16.2  0.608
# 10            Stephen Curry  PG   34  GSW  38  38  34.6   9.8  19.8  0.495
# ...

# %%
combined.to_csv("combined.csv")

# %%
combined.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'PER',
#        'USG%', 'TS%', '3PAr', 'FTr', 'TRB%', 'AST%', 'STL%', 'BLK%'],
#       dtype='object')
